# %% [markdown]
# # 1. Importing

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# %% [markdown]
# # 2. Loading the Data

# %%
df = pd.read_csv("companies.csv")

# %% [markdown]
# # 3. Normalize Column Names

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# Display basic info
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196553 entries, 0 to 196552
# Data columns (total 44 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   196553 non-null  object
#  1   unnamed:_0.1         196553 non-null  int64
#  2   entity_type          196553 non-null  object
#  3   entity_id            196553 non-null  int64
#  4   parent_id            0 non-null       float64
#  5   name                 196531 non-null  object
#  6   normalized_name      196527 non-null  object
#  7   permalink            196553 non-null  object
#  8   category_code        123186 non-null  object
#  9   status               196553 non-null  object
#  10  founded_at           91227 non-null   object
#  11  closed_at            2620 non-null    object
#  12  domain               126545 non-null  object
#  13  homepage_url         126545 non-null  object
#  14  twitter_username     80591 non-null   object
#  15  logo_url             110110 non-null  object
#  16  logo_width           110110 non-null  float64
#  17  logo_height          110110 non-null  float64
#  18  short_description    7131 non-null    object
#  19  description          92048 non-null   object
#  20  overview             126971 non-null  object
#  21  tag_list             81452 non-null   object
#  22  country_code         87990 non-null   object
#  23  state_code           50903 non-null   object
#  24  city                 83890 non-null   object
#  25  region               196553 non-null  object
#  26  first_investment_at  2583 non-null    object
#  27  last_investment_at   2583 non-null    object
#  28  investment_rounds    2591 non-null    float64
#  29  invested_companies   2591 non-null    float64
#  30  first_funding_at     31507 non-null   object
#  31  last_funding_at      31507 non-null   object
#  32  funding_rounds       31707 non-null   float64
#  33  funding_total_usd    27874 non-null   float64
#  34  first_milestone_at   91699 non-null   object
#  35  last_milestone_at    91699 non-null   object
#  36  milestones           91699 non-null   float64
#  37  relationships        129667 non-null  float64
#  38  created_by           155533 non-null  object
#  39  created_at           196553 non-null  object
#  40  updated_at           196553 non-null  object
#  41  lat                  83852 non-null   float64
#  42  lng                  83852 non-null   float64
#  43  roi                  726 non-null     float64
# dtypes: float64(12), int64(2), object(30)
# memory usage: 66.0+ MB
#         id  unnamed:_0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...         2010-09-05        2013-09-18
# 1      games_video   acquired  ...                NaN               NaN
# 2      games_video   acquired  ...         2003-02-01        2011-09-23
# 3  network_hosting  operating  ...                NaN               NaN
# 4      games_video  operating  ...                NaN               NaN
#
#   milestones relationships        created_by           created_at  \
# 0        5.0          17.0  initial-importer  2007-05-25 06:51:27
# 1        NaN           6.0  initial-importer  2007-05-31 21:11:51
# 2        4.0          12.0  initial-importer  2007-08-06 23:52:45
# 3        NaN           NaN               NaN  2008-08-24 16:51:57
# 4        NaN           NaN               NaN  2008-08-24 17:10:34
#
#             updated_at        lat         lng   roi
# 0  2013-04-13 03:29:00  47.606209 -122.332071  15.5
# 1  2008-05-23 23:23:14  34.021122 -118.396467   NaN
# 2  2013-11-04 02:09:48  37.562992 -122.325525   NaN
# 3  2008-09-06 14:19:18        NaN         NaN   NaN
# 4  2008-09-06 14:19:18        NaN         NaN   NaN
#
# [5 rows x 44 columns]

# %% [markdown]
# # 4. Drop Irrelevant Columns

# %%
columns_to_drop = [
    'Unnamed: 0.1', 'created_at', 'created_by', 'updated_at',
    'logo_url', 'logo_width', 'logo_height',
    'overview', 'permalink'
]
df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# %% [markdown]
# # 5. Remove Rows Missing Essential Identifiers

# %%
df = df.dropna(subset=['name', 'status'])

# %% [markdown]
# # 6. Fill Non-Critical Missing Values with Placeholders

# %%
fill_na_with_placeholder = {
    'description': 'Not Provided',
    'short_description': 'Not Provided',
    'country_code': 'Unknown',
    'state_code': 'Unknown',
    'city': 'Unknown',
    'region': 'Unknown'
}
df.fillna(value=fill_na_with_placeholder, inplace=True)

# %% [markdown]
# # 7. Parse Date and Numeric Columns

# %%
date_columns = ['founded_at', 'first_funding_at', 'last_milestone_at']
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')

numeric_columns = ['funding_total_usd', 'investment_rounds', 'roi']
for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %% [markdown]
# # 8. Ensure Categorical Columns Are Strings

# %%
categorical_columns = ['status', 'category_code', 'city']
for col in categorical_columns:
    df[col] = df[col].astype(str)

# %% [markdown]
# # 9. Clean Up Geographical Coordinates

# %%
df['lat'] = pd.to_numeric(df['lat'], errors='coerce')
df['lng'] = pd.to_numeric(df['lng'], errors='coerce')

# %% [markdown]
# # 10. Feature Engineering

# %%
# Calculate company age
if 'founded_at' in df.columns:
    df['founded_year'] = df['founded_at'].dt.year
    df['company_age'] = 2025 - df['founded_year']

# %% [markdown]
# # 11. Encode Categorical Features

# %%
label_encodable = ['country_code', 'state_code', 'city', 'region', 'category_code']
for col in label_encodable:
    if col in df.columns:
        df[col] = LabelEncoder().fit_transform(df[col])

# %% [markdown]
# # 12. Added Active_Status column.

# %%
def label_status(status):
    if status in ['operating', 'ipo']:
        return 1  # Active
    elif status in ['acquired', 'closed']:
        return 0  # Not Active
    else:
        return np.nan  # unknown

df['active_status'] = df['status'].apply(label_status)

# Drop rows with unknown status labels
df.dropna(subset=['active_status'], inplace=True)
df['active_status'] = df['active_status'].astype(int)

# %%
df.columns
# Out:
# Index(['id', 'unnamed:_0.1', 'entity_type', 'entity_id', 'parent_id', 'name',
#        'normalized_name', 'category_code', 'status', 'founded_at', 'closed_at',
#        'domain', 'homepage_url', 'twitter_username', 'short_description',
#        'description', 'tag_list', 'country_code', 'state_code', 'city',
#        'region', 'first_investment_at', 'last_investment_at',
#        'investment_rounds', 'invested_companies', 'first_funding_at',
#        'last_funding_at', 'funding_rounds', 'funding_total_usd',
#        'first_milestone_at', 'last_milestone_at', 'milestones',
#        'relationships', 'lat', 'lng', 'roi', 'founded_year', 'company_age',
#        'active_status'],
#       dtype='object')

# %% [markdown]
# # 13. Save the Cleaned Data into CSV

# %%
df.to_csv("Data Preprocessing_companies.csv", index=False)

# %%
df
# Out:
#              id  unnamed:_0.1 entity_type  entity_id  parent_id  \
# 0           c:1             0     Company          1        NaN
# 1          c:10             1     Company         10        NaN
# 2         c:100             2     Company        100        NaN
# 3       c:10000             3     Company      10000        NaN
# 4       c:10001             4     Company      10001        NaN
# ...         ...           ...         ...        ...        ...
# 196548  c:99940        196548     Company      99940        NaN
# 196549   c:9995        196549     Company       9995        NaN
# 196550   c:9996        196550     Company       9996        NaN
# 196551   c:9997        196551     Company       9997        NaN
# 196552   c:9998        196552     Company       9998        NaN
#
#                       name     normalized_name  category_code     status  \
# 0                 Wetpaint            wetpaint             42  operating
# 1                  Flektor             flektor             12   acquired
# 2                    There               there             12   acquired
# 3                  MYWEBBO             mywebbo             26  operating
# 4       THE Movie Streamer  the movie streamer             12  operating
# ...                    ...                 ...            ...        ...
# 196548           Webgility           webgility              7  operating
# 196549              FohBoh              fohboh             32  operating
# 196550                 CSC                 csc              5  operating
# 196551       Top-candidate       top candidate             34  operating
# 196552      Closet Couture      closet couture              7  operating
#
#        founded_at  ... first_milestone_at last_milestone_at milestones  \
# 0      2005-10-17  ...         2010-09-05        2013-09-18        5.0
# 1             NaT  ...                NaN               NaT        NaN
# 2             NaT  ...         2003-02-01        2011-09-23        4.0
# 3      2008-07-26  ...                NaN               NaT        NaN
# 4      2008-07-26  ...                NaN               NaT        NaN
# ...           ...  ...                ...               ...        ...
# 196548 2007-01-01  ...         2013-08-12        2013-08-12        2.0
# 196549 2007-11-01  ...         2013-05-01        2013-05-01        1.0
# 196550 1959-01-01  ...         2012-01-01        2013-10-30        3.0
# 196551 2008-07-01  ...                NaN               NaT        NaN
# 196552 2007-09-01  ...         2006-07-01        2008-09-10        2.0
#
#        relationships        lat         lng   roi  founded_year  company_age  \
# 0               17.0  47.606209 -122.332071  15.5        2005.0         20.0
# 1                6.0  34.021122 -118.396467   NaN           NaN          NaN
# 2               12.0  37.562992 -122.325525   NaN           NaN          NaN
# 3                NaN        NaN         NaN   NaN        2008.0         17.0
# 4                NaN        NaN         NaN   NaN        2008.0         17.0
# ...              ...        ...         ...   ...           ...          ...
# 196548           5.0  37.774929 -122.419415   NaN        2007.0         18.0
# 196549          14.0  37.338208 -121.886329   NaN        2007.0         18.0
# 196550          44.0  38.882334  -77.171091   NaN        1959.0         66.0
# 196551           1.0  34.052234 -118.243685   NaN        2008.0         17.0
# 196552           1.0  34.035633 -118.515590   NaN        2007.0         18.0
#
#         active_status
# 0                   1
# 1                   0
# 2                   0
# 3                   1
# 4                   1
# ...               ...
# 196548              1
# 196549              1
# 196550              1
# 196551              1
# 196552              1
#
# [196531 rows x 39 columns]
